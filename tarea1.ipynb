# %%
############### Librerias ################
import pandas as pd # para dataframe
#import matplotlib.pyplot as plt # para graficos
##########################################
d_parentLevel={"some high school":1,
               "high school":2,
               "some college":3,
               "associate's degree":4,
               "bachelor's degree":5,
               "master's degree":6}# es ese el orden ??
d_gender={"female":0,"male":1}
def changeLunch(lunch):
    return 1 if lunch=="standard" else 0
def changeTestPreparationCourse(test):
    return 1 if test=="completed" else 0
def changeParentalLevelOfEducation(level):
    return d_parentLevel[level]
def changeGender(gender):
    return d_gender[gender]
###########################################
def convertirAValoresNumericos():
    doc["lunch"]=doc["lunch"].apply(changeLunch)
    doc["test preparation course"]=doc["test preparation course"].apply(changeTestPreparationCourse)
    doc["parental level of education"]=doc["parental level of education"].apply(changeParentalLevelOfEducation)
    #doc["gender"]=doc["gender"].apply(changeGender)

    #abrimos el archivo
doc=pd.read_csv('StudentsPerformance.csv')
    
#buscamos valores nulos    
print("----valores nulos----\n",doc.isnull().sum())#no hay valores perdidos en ninguno

#eliminacion de columnas
doc=doc.drop('race/ethnicity',axis=1)#esta se elimina???

#verificamos los tipos de datos y los convertimos a valores numericos
print("----tipos de datos----\n",doc.dtypes.value_counts())
convertirAValoresNumericos()#por funciones
doc=doc.replace(d_gender)#o directamente
print("----tipos de datos convertidos----\n",doc.dtypes.value_counts())

#doc.to_csv("doc.csv",index=False) ##en caso de querer guardarlo
doc_columns = ['math score','reading score',"writing score"]
doc[doc_columns].plot.hist(alpha=0.3,bins=20);
doc

columns=filtered_loans.columns
X=filtered_loans[columns[0:len(columns)-2]]
y=filtered_loans[columns[len(columns)-2]]

from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

#from sklearn.model_selection import KFold

#kf = KFold(n_splits=5,shuffle=True)
#for k, (train_index, test_index) in enumerate(kf.split(X, y)):
#    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
#    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

#doc["math score"].value_counts()
# Out:
# ----valores nulos----
#  gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64
# ----tipos de datos----
#  object    4
# int64     3
# dtype: int64
# ----tipos de datos convertidos----
#  int64    7
# dtype: int64
#      gender  parental level of education  lunch  test preparation course  \
# 0         0                            5      1                        0
# 1         0                            3      1                        1
# 2         0                            6      1                        0
# 3         1                            4      0                        0
# 4         1                            3      1                        0
# ..      ...                          ...    ...                      ...
# ...
